# %% [markdown]
# ￥print￥

# %% [markdown]
# $print$

# %% [markdown]
# $e^{i\pi}+1 = 0$

# %% [markdown]
# <img src='./Pictures/Feedback/specax.jpg' width=200>

# %%
from IPython.display import Image

# %%
Image(filename=r'C:\Users\刘宗昊\Pictures\Feedback\specax.jpg',width=200)

# %% [markdown]
# 插入表格
#
# | 第一栏   | 第二栏 | 第三栏|
# |-----------|:-----------:|------|
# | col 3 is | right-aligned| 1600|
# | col 2 is | centered | 12 |
# | zebra stripes | are neat | 1 |
